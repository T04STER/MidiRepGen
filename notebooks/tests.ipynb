# %%
# %load_ext autoreload
# %autoreload 2
from src.models.representation.vae import *
from src.models.representation.vae.vae import RecurrentVaeWithTeacherForcing
from src.models.representation.vae.decoder.recurrent_decoder import LSTMVaeDecoderWithTeacherForcing
from src.dataloader.dataset import PianoRollMidiDataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle

import torch

dataset: PianoRollMidiDataset = pickle.load(open("data/preprocessed_piano_roll.pkl", "rb"))

# %%
from torch.utils.data import DataLoader
encoder = LSTMVaeEncoder(
    60, 
    256,
    128,
    2
)
decoder = LSTMVaeDecoderWithTeacherForcing(
    128, 
    256,
    2,
    60,
    60,
    teacher_forcing_ratio=0.5,
)

vae = RecurrentVaeWithTeacherForcing(encoder, decoder).cuda()


midi_dataloader = DataLoader(
    dataset,
    batch_size=16,
    pin_memory=True,
    num_workers=4,
    shuffle=True,
)


t = next(iter(midi_dataloader))

# %%
t.shape
# Out:
# torch.Size([16, 640, 60])

# %%
vae(t.cuda())
# Out:
# (tensor([[[ 0.1006, -0.0525,  0.0728,  ..., -0.0836, -0.0918,  0.1241],
#           [ 0.0504, -0.0584,  0.0566,  ..., -0.0186, -0.0390,  0.0947],
#           [ 0.0160, -0.0534,  0.0508,  ...,  0.0164, -0.0137,  0.0740],
#           ...,
#           [-0.0070, -0.0500,  0.0587,  ...,  0.0510,  0.0238,  0.0504],
#           [-0.0075, -0.0493,  0.0566,  ...,  0.0500,  0.0224,  0.0509],
#           [-0.0082, -0.0486,  0.0546,  ...,  0.0481,  0.0212,  0.0514]],
#
#          [[-0.1189, -0.1134,  0.2766,  ..., -0.0458,  0.0868, -0.0860],
#           [-0.0725, -0.0871,  0.1930,  ...,  0.0188,  0.0472, -0.0229],
#           [-0.0413, -0.0748,  0.1348,  ...,  0.0418,  0.0270,  0.0103],
#           ...,
#           [-0.0088, -0.0456,  0.0553,  ...,  0.0400,  0.0192,  0.0535],
#           [-0.0094, -0.0460,  0.0544,  ...,  0.0403,  0.0190,  0.0527],
#           [-0.0100, -0.0466,  0.0534,  ...,  0.0406,  0.0188,  0.0521]],
#
#          [[ 0.0046, -0.0274,  0.1527,  ...,  0.0483,  0.1029,  0.0463],
#           [ 0.0262, -0.0126,  0.1173,  ...,  0.0464,  0.0739,  0.0370],
#           [ 0.0251, -0.0167,  0.0956,  ...,  0.0514,  0.0494,  0.0336],
#           ...,
#           [-0.0114, -0.0451,  0.0597,  ...,  0.0419,  0.0213,  0.0584],
#           [-0.0108, -0.0459,  0.0582,  ...,  0.0416,  0.0211,  0.0564],
#           [-0.0106, -0.0466,  0.0564,  ...,  0.0414,  0.0208,  0.0545]],
#
#          ...,
#
#          [[ 0.0158, -0.0607,  0.1163,  ..., -0.0337,  0.0690,  0.0812],
#           [ 0.0186, -0.0460,  0.0719,  ...,  0.0203,  0.0459,  0.0729],
#           [ 0.0010, -0.0477,  0.0622,  ...,  0.0467,  0.0310,  0.0659],
#           ...,
#           [-0.0140, -0.0498,  0.0513,  ...,  0.0432,  0.0204,  0.0483],
#           [-0.0134, -0.0489,  0.0515,  ...,  0.0432,  0.0203,  0.0486],
#           [-0.0129, -0.0482,  0.0516,  ...,  0.0429,  0.0202,  0.0492]],
#
#          [[-0.0316, -0.0093,  0.0201,  ..., -0.0414, -0.0102, -0.0210],
#           [ 0.0158, -0.0362,  0.0181,  ..., -0.0174, -0.0090,  0.0131],
#           [ 0.0170, -0.0521,  0.0193,  ...,  0.0078, -0.0091,  0.0337],
#           ...,
#           [-0.0214, -0.0515,  0.0467,  ...,  0.0332,  0.0190,  0.0606],
#           [-0.0193, -0.0514,  0.0481,  ...,  0.0337,  0.0195,  0.0589],
#           [-0.0171, -0.0511,  0.0493,  ...,  0.0352,  0.0197,  0.0567]],
#
#          [[-0.1478,  0.1746, -0.1180,  ...,  0.1391, -0.0371,  0.0531],
#           [-0.0869,  0.0886, -0.0075,  ...,  0.0883,  0.0007,  0.0746],
#           [-0.0457,  0.0291,  0.0392,  ...,  0.0622,  0.0080,  0.0672],
#           ...,
#           [-0.0132, -0.0482,  0.0518,  ...,  0.0418,  0.0208,  0.0508],
#           [-0.0129, -0.0480,  0.0523,  ...,  0.0417,  0.0207,  0.0512],
#           [-0.0126, -0.0479,  0.0525,  ...,  0.0416,  0.0204,  0.0514]]],
#         device='cuda:0', grad_fn=<CatBackward0>),
#  tensor([[-0.0385,  0.0071,  0.0273,  ...,  0.0598, -0.0004,  0.0838],
#          [-0.0326,  0.0053,  0.0298,  ...,  0.0505, -0.0037,  0.0806],
#          [-0.0402,  0.0047,  0.0375,  ...,  0.0544, -0.0080,  0.0760],
#          ...,
#          [-0.0292,  0.0059,  0.0342,  ...,  0.0486, -0.0035,  0.0801],
#          [-0.0284, -0.0003,  0.0204,  ...,  0.0519,  0.0022,  0.0650],
#          [-0.0338,  0.0077,  0.0301,  ...,  0.0487, -0.0049,  0.0794]],
#         device='cuda:0', grad_fn=<AddmmBackward0>),
#  tensor([[ 0.0209, -0.0279, -0.0448,  ...,  0.0097,  0.0197, -0.0281],
#          [ 0.0179, -0.0261, -0.0464,  ...,  0.0137,  0.0240, -0.0169],
#          [ 0.0171, -0.0367, -0.0509,  ...,  0.0182,  0.0124, -0.0229],
#          ...,
#          [ 0.0229, -0.0251, -0.0537,  ...,  0.0072,  0.0204, -0.0229],
#          [ 0.0236, -0.0296, -0.0445,  ...,  0.0098,  0.0169, -0.0164],
#          [ 0.0198, -0.0274, -0.0520,  ...,  0.0143,  0.0225, -0.0190]],
#         device='cuda:0', grad_fn=<AddmmBackward0>))

# %%
import torch

optimizer = torch.optim.Adam(
    vae.parameters(),
    lr=5*1e-4,
)

loss_fn = VaeLoss(reduction="mean")

trainer = VaeTrainer(
    vae,
    optimizer,
    loss_fn,
    "test/simple_vae",
    10
)

print(t.shape)
trainer.train(midi_dataloader, epochs=10)
trainer.save("test/simple_vae_final.pth")
# Out:
# torch.Size([16, 640, 60])
# Epoch [1/10], Loss: 0.0972, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0604, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0468, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0401, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0359, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0331, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0310, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0291, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0277, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0265, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0254, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0246, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0238, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0231, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0224, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0218, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0212, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0207, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0202, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0197, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0193, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0189, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0185, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0181, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0178, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0175, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0171, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0168, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0165, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0162, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0160, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0157, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0154, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0151, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0149, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0147, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0144, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0142, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0140, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0138, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0136, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0134, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0132, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0130, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0128, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0127, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0125, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0123, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0122, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0120, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0119, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0117, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0116, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0115, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0113, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0112, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0111, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0110, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0109, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0107, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0106, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0105, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0104, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0103, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0102, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0101, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0100, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0099, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0099, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0098, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0097, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0096, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0095, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0094, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0093, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0093, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0092, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0091, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0090, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0090, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0089, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0088, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0088, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0087, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0086, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0086, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0085, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0084, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0084, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0083, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0083, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0082, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0081, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0081, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0080, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0080, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0079, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0079, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0078, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0078, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0077, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0077, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0076, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0076, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0076, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0075, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0075, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0074, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0074, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0073, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0073, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0073, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0072, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0072, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0071, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0071, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0071, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0070, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0070, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0069, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0069, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0069, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0068, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0068, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0068, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0067, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0067, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0067, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0066, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0066, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0066, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0065, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0065, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0065, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0065, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0064, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0064, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0064, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0063, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0063, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0063, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0063, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0062, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0062, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0062, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0061, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0061, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0061, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0061, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0060, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0060, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0060, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0060, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0059, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0059, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0059, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0059, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0059, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0058, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0058, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0058, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0058, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0057, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0057, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0057, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0057, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0057, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0056, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0056, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0056, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0056, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0056, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0055, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0055, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0055, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0055, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0055, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0055, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0054, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0054, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0054, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0054, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0054, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0053, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0053, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0053, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0053, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0053, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0053, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0053, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0052, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0052, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0052, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0052, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0052, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0052, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0052, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0051, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0051, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0051, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0051, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0051, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0051, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0051, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0050, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0050, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0050, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0050, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0050, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0050, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0050, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0050, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0049, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0049, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0049, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0049, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0049, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0049, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0049, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0049, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0048, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0047, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0046, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0045, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0044, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0044, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0044, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0044, Run: test/simple_vae
# Epoch [1/10], Loss: 0.0044, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0025, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0024, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0023, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0023, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0023, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0022, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# Epoch [2/10], Loss: 0.0021, Run: test/simple_vae
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[210], line 19
#      10 trainer = VaeTrainer(
#      11     vae,
#      12     optimizer,
#    (...)     15     10
#      16 )
#      18 print(t.shape)
# ---> 19 trainer.train(midi_dataloader, epochs=10)
#      20 trainer.save("test/simple_vae_final.pth")
#
# File ~/MidiRepGen/src/models/representation/vae/vae_trainer.py:30, in VaeTrainer.train(self, dataloader, epochs)
#      28 for i, batch in enumerate(dataloader):
#      29     batch = batch.to(self.device)
# ---> 30     loss = self.train_step(batch)
#      31     total_loss += loss
#      32     if (i + 1) % self.log_every_n_epochs == 0:
#
# File ~/MidiRepGen/src/models/representation/vae/vae_trainer.py:20, in VaeTrainer.train_step(self, data)
#      18 reconstructed, mu, log_var = self.model(data)
#      19 loss = self.loss_fn(reconstructed, data, mu, log_var)
# ---> 20 loss.backward()
#      21 self.optimizer.step()
#      23 return loss.item()
#
# File ~/MidiRepGen/.venv/lib/python3.11/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/MidiRepGen/.venv/lib/python3.11/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File ~/MidiRepGen/.venv/lib/python3.11/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
vae.encoder(t[0].unsqueeze(1).cuda())
# Out:
# (tensor([[-0.0248,  0.0115,  0.0160,  ...,  0.0180,  0.0075,  0.0356],
#          [-0.0248,  0.0115,  0.0160,  ...,  0.0180,  0.0075,  0.0356],
#          [-0.0248,  0.0115,  0.0160,  ...,  0.0180,  0.0075,  0.0356],
#          ...,
#          [-0.0246,  0.0114,  0.0162,  ...,  0.0181,  0.0073,  0.0356],
#          [-0.0246,  0.0114,  0.0162,  ...,  0.0181,  0.0073,  0.0356],
#          [-0.0246,  0.0114,  0.0162,  ...,  0.0181,  0.0073,  0.0356]],
#         device='cuda:0', grad_fn=<AddmmBackward0>),
#  tensor([[ 0.0085, -0.0079, -0.0192,  ...,  0.0020,  0.0171, -0.0065],
#          [ 0.0085, -0.0079, -0.0192,  ...,  0.0020,  0.0171, -0.0065],
#          [ 0.0085, -0.0079, -0.0192,  ...,  0.0020,  0.0171, -0.0065],
#          ...,
#          [ 0.0086, -0.0080, -0.0193,  ...,  0.0019,  0.0170, -0.0065],
#          [ 0.0086, -0.0080, -0.0193,  ...,  0.0019,  0.0170, -0.0065],
#          [ 0.0086, -0.0080, -0.0193,  ...,  0.0019,  0.0170, -0.0065]],
#         device='cuda:0', grad_fn=<AddmmBackward0>))

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from tqdm import tqdm


@torch.inference_mode
def plot_pca(samples: list[tuple[torch.Tensor, torch.Tensor]]):
    all_latents = []
    for mu, logvar in samples:
        reparam = mu + torch.randn_like(logvar) * torch.exp(0.5 * logvar)
        all_latents.append(reparam.cpu().numpy())

    all_latents = np.concatenate(all_latents, axis=0)
    pca = PCA(n_components=2)
    reduced = pca.fit_transform(all_latents)

    plt.scatter(reduced[:, 0], reduced[:, 1])
    plt.title("PCA of Latent Space")
    plt.xlabel("PC1")
    plt.ylabel("PC2")
    plt.show()

vae.eval()
eg_samples = []
for i in tqdm(range(200)):
    t = next(iter(midi_dataloader))
    mu, logvar = vae.encoder(t.cuda())
    eg_samples.append((mu, logvar))

plot_pca(eg_samples)
# Out:
# 100%|██████████| 200/200 [01:13<00:00,  2.72it/s]

# %%
import pretty_midi

noise = torch.randn(1000, 128).cuda()

@torch.inference_mode
def sampler(noise, sqe_length, vae: RecurrentVae):
    """
    Sample from the VAE using the provided noise.
    """
    vae.eval()
    # Encode the noise
    # Decode to get the generated sequence
    generated_sequence = vae.decoder(noise, seq_length=sqe_length)
    return generated_sequence
    
eg_track = sampler(noise, 640, vae)

# %%
def print_track_stats(track: torch.Tensor):
    """
    Print statistics of the track.
    """
    scaled = (track * 127.0).clamp(0, 127)
    print(f"Track shape: {track.shape} ")
    print(f"Track min: {track.min()} | scaled min: {scaled.min()}")
    print(f"Track max: {track.max()} | scaled max: {scaled.max()}")
    print(f"Track mean: {track.mean()} | scaled mean: {scaled.mean()}")
    print(f"Track std: {track.std()} | scaled std: {scaled.std()}")
    

print_track_stats(eg_track)
# Out:
# Track shape: torch.Size([1000, 640, 60])
# Track min: -0.18139925599098206 | scaled min: 0.0
# Track max: 0.23133166134357452 | scaled max: 29.379121780395508
# Track mean: -0.0029741295147687197 | scaled mean: 2.0014400482177734
# Track std: 0.04477953910827637 | scaled std: 3.141443967819214

# %%
print_track_stats(t)
# Out:
# Track shape: torch.Size([16, 640, 60])
# Track min: 0.0 | scaled min: 0.0
# Track max: 0.834645688533783 | scaled max: 106.0
# Track mean: 0.047652602195739746 | scaled mean: 6.0518798828125
# Track std: 0.1586504429578781 | scaled std: 20.14860725402832

# %%
print_track_stats(vae(t.cuda())[0])
# Out:
# Track shape: torch.Size([16, 640, 60])
# Track min: -0.24507708847522736 | scaled min: 0.0
# Track max: 0.9801698923110962 | scaled max: 124.48157501220703
# Track mean: 0.04459753260016441 | scaled mean: 6.366756439208984
# Track std: 0.1512681245803833 | scaled std: 18.926008224487305

# %%
def piano_roll_to_pretty_midi(piano_roll, fs=64, path="eg.mid", pitch_range=(24, 84)):
    """
    Convert a piano roll (tensor or array) to a MIDI file using pretty_midi.
    Expects piano_roll to be shape [time, pitch] and in range [0, 1].
    """
    if isinstance(piano_roll, torch.Tensor):
        piano_roll = (piano_roll * 127).clamp(0, 127).detach().cpu().numpy().astype(np.int32)
    
    pm = pretty_midi.PrettyMIDI()
    instrument = pretty_midi.Instrument(program=0)
    
    pitch_offset = pitch_range[0]
    time_steps, pitch_count = piano_roll.shape
    
    # Process each pitch to create sustained notes
    for pitch_idx in range(pitch_count):
        pitch = pitch_idx + pitch_offset
        
        # Find note onsets and offsets
        note_on = False
        note_start = 0
        
        for time in range(time_steps):
            velocity = piano_roll[time, pitch_idx]
            
            if velocity > 0 and not note_on:
                # Note starts
                note_on = True
                note_start = time
                note_velocity = int(velocity)
            elif velocity == 0 and note_on:
                # Note ends
                note_on = False
                note = pretty_midi.Note(
                    velocity=note_velocity,
                    pitch=pitch,
                    start=note_start / fs,
                    end=time / fs
                )
                instrument.notes.append(note)
        
        # Handle note that extends to end
        if note_on:
            note = pretty_midi.Note(
                velocity=note_velocity,
                pitch=pitch,
                start=note_start / fs,
                end=time_steps / fs
            )
            instrument.notes.append(note)
    
    pm.instruments.append(instrument)
    pm.write(path)

piano_roll_to_pretty_midi(eg_track[0], path="eg.mid")

# %%
track_reco, _, _ = vae(t.cuda())
piano_roll_to_pretty_midi(track_reco[0], path="reco.mid")

# %%
track_true = t[0]
piano_roll_to_pretty_midi(track_true, path="true.mid")

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from scipy import ndimage

def plot_pitch_changes(piano_roll, fs=64, pitch_range=(24, 84), method='heatmap'):
    """
    Plot pitch changes from piano roll data in various ways.
    
    Args:
        piano_roll: Piano roll tensor/array [time, pitch]
        fs: Sample rate (frames per second)
        pitch_range: (min_pitch, max_pitch) MIDI note numbers
        method: 'heatmap', 'dominant', 'centroid', 'active_notes', or 'all'
    """
    if isinstance(piano_roll, torch.Tensor):
        piano_roll = piano_roll.detach().cpu().numpy()
    
    time_steps, pitch_count = piano_roll.shape
    time_axis = np.arange(time_steps) / fs
    pitch_axis = np.arange(pitch_range[0], pitch_range[0] + pitch_count)
    
    if method == 'heatmap' or method == 'all':
        plot_piano_roll_heatmap(piano_roll, time_axis, pitch_axis)
    
    if method == 'dominant' or method == 'all':
        plot_dominant_pitch(piano_roll, time_axis, pitch_axis)
    
    if method == 'centroid' or method == 'all':
        plot_pitch_centroid(piano_roll, time_axis, pitch_axis)
    
    if method == 'active_notes' or method == 'all':
        plot_active_notes(piano_roll, time_axis, pitch_axis)
    
    plt.tight_layout()
    plt.show()

def plot_piano_roll_heatmap(piano_roll, time_axis, pitch_axis):
    """Plot piano roll as a heatmap showing all pitch activity over time."""
    plt.figure(figsize=(12, 6))
    plt.imshow(piano_roll.T, aspect='auto', origin='lower', 
               extent=[time_axis[0], time_axis[-1], pitch_axis[0], pitch_axis[-1]],
               cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Velocity')
    plt.xlabel('Time (seconds)')
    plt.ylabel('MIDI Pitch')
    plt.title('Piano Roll Heatmap - All Pitch Activity')
    
    # Add note names for reference
    note_names = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    octave_ticks = [i for i in range(int(pitch_axis[0]), int(pitch_axis[-1]), 12)]
    octave_labels = [f"{note_names[tick % 12]}{tick // 12 - 1}" for tick in octave_ticks]
    plt.yticks(octave_ticks, octave_labels)

def plot_dominant_pitch(piano_roll, time_axis, pitch_axis):
    """Plot the dominant (loudest) pitch at each time step."""
    dominant_pitches = []
    dominant_velocities = []
    
    for t in range(len(time_axis)):
        frame = piano_roll[t, :]
        if np.max(frame) > 0:
            dominant_idx = np.argmax(frame)
            dominant_pitches.append(pitch_axis[dominant_idx])
            dominant_velocities.append(frame[dominant_idx])
        else:
            dominant_pitches.append(np.nan)
            dominant_velocities.append(0)
    
    plt.figure(figsize=(12, 6))
    plt.plot(time_axis, dominant_pitches, 'b-', linewidth=2, alpha=0.7)
    plt.xlabel('Time (seconds)')
    plt.ylabel('MIDI Pitch')
    plt.title('Dominant Pitch Over Time')
    plt.grid(True, alpha=0.3)

def plot_pitch_centroid(piano_roll, time_axis, pitch_axis):
    """Plot the pitch centroid (weighted average pitch) over time."""
    centroids = []
    
    for t in range(len(time_axis)):
        frame = piano_roll[t, :]
        if np.sum(frame) > 0:
            # Weighted average pitch
            centroid = np.sum(pitch_axis * frame) / np.sum(frame)
            centroids.append(centroid)
        else:
            centroids.append(np.nan)
    
    plt.figure(figsize=(12, 6))
    plt.plot(time_axis, centroids, 'r-', linewidth=2, alpha=0.7)
    plt.xlabel('Time (seconds)')
    plt.ylabel('MIDI Pitch')
    plt.title('Pitch Centroid Over Time (Weighted Average)')
    plt.grid(True, alpha=0.3)

def plot_active_notes(piano_roll, time_axis, pitch_axis, threshold=0.1):
    """Plot all active notes as separate lines over time."""
    plt.figure(figsize=(12, 8))
    
    # Normalize piano roll for better visualization
    piano_roll_norm = piano_roll / np.max(piano_roll) if np.max(piano_roll) > 0 else piano_roll
    
    colors = plt.cm.tab20(np.linspace(0, 1, len(pitch_axis)))
    
    for pitch_idx, pitch in enumerate(pitch_axis):
        activity = piano_roll_norm[:, pitch_idx]
        
        # Only plot pitches that have some activity
        if np.max(activity) > threshold:
            # Create y-values that show note activity
            y_values = np.where(activity > threshold, pitch, np.nan)
            plt.plot(time_axis, y_values, 'o-', color=colors[pitch_idx % len(colors)], 
                    markersize=3, alpha=0.7, linewidth=1)
    
    plt.xlabel('Time (seconds)')
    plt.ylabel('MIDI Pitch')
    plt.title('Active Notes Over Time')
    plt.grid(True, alpha=0.3)

def analyze_pitch_transitions(piano_roll, fs=64, pitch_range=(24, 84)):
    """Analyze pitch transitions and movement patterns."""
    if isinstance(piano_roll, torch.Tensor):
        piano_roll = piano_roll.detach().cpu().numpy()
    
    time_steps, pitch_count = piano_roll.shape
    pitch_axis = np.arange(pitch_range[0], pitch_range[0] + pitch_count)
    
    # Calculate pitch centroids
    centroids = []
    for t in range(time_steps):
        frame = piano_roll[t, :]
        if np.sum(frame) > 0:
            centroid = np.sum(pitch_axis * frame) / np.sum(frame)
            centroids.append(centroid)
        else:
            centroids.append(np.nan)
    
    centroids = np.array(centroids)
    
    # Calculate pitch changes (derivatives)
    valid_mask = ~np.isnan(centroids)
    pitch_changes = np.diff(centroids[valid_mask])
    
    # Statistics
    print("Pitch Movement Analysis:")
    print(f"Average pitch: {np.nanmean(centroids):.2f}")
    print(f"Pitch range: {np.nanmin(centroids):.2f} - {np.nanmax(centroids):.2f}")
    print(f"Average pitch change: {np.mean(np.abs(pitch_changes)):.2f} semitones")
    print(f"Max upward jump: {np.max(pitch_changes):.2f} semitones")
    print(f"Max downward jump: {np.min(pitch_changes):.2f} semitones")
    
    # Plot pitch change histogram
    plt.figure(figsize=(10, 6))
    plt.hist(pitch_changes, bins=50, alpha=0.7, edgecolor='black')
    plt.xlabel('Pitch Change (semitones)')
    plt.ylabel('Frequency')
    plt.title('Distribution of Pitch Changes')
    plt.grid(True, alpha=0.3)
    plt.axvline(0, color='red', linestyle='--', alpha=0.7, label='No change')
    plt.legend()
    plt.show()
    
    return centroids, pitch_changes

plot_pitch_changes(track_reco[0])
# centroids, changes = analyze_pitch_transitions(track_reco[0])

# %%
plot_pitch_changes(track_true)
